# %% [markdown]
# # UAI 655 Pandas training
#
# # Pandas Exercises for Biochemists

# %% [markdown]
# # Team 2

# %% [markdown]
# Division is:
#
# | Team | Assigned Set | Focus on |
# |-----|-----------|----------|
# | **Team 1** | Set 1 | Protein Expression Data Analysis |
# | **Team 2** | Set 2 | Metabolite Concentration Time Series |
# | **Team 3** | Set 3 | Enzyme Kinetics and Inhibition Studies |
# | **Team 4** | Set 4 | Genomics and Proteomics Integration |
#
# ### Every team will have:
# - **5 tasks** (1.1 to 1.5 for Team1 etc.)
# - Combanation of pandas, numpy, itertools, matplotlib
# - Biochemical focus specific for its SetBiochemické zaměření specifické pro jejich sadu
#
# ### Organizational notes:
#
# 1. **No overlays** – every Set is tematically separated
# 2. **Same difficulty** – all Sets are approximately of the same difficulty
# 3. **Can be solved paralelly** – Teams are independent
# 4. **Bonus code** for data generation is common - attached to every Team

# %% [markdown]
# Here are **4 sets** of pandas exercises, each with **5 examples**, tailored for biochemistry data analysis. Each set combines pandas with numpy, itertools, or matplotlib.

# %% [markdown]
# ## Set 2: Metabolite Concentration Time Series
#
# **Dataset concept**: Metabolite concentrations (mM) measured over time after drug treatment
#
# ### Exercise 2.1
# Create a DataFrame with time points (0, 15, 30, 60, 120, 240 minutes) and 10 metabolites. Use numpy to add random noise (normal distribution, mean=0, std=0.05 * concentration) to simulate measurement error. Then calculate the rolling mean with window size 2.
#
# ### Exercise 2.2
# Using `itertools.cycle`: Assign each metabolite to one of 3 classes (Amino acid, Lipid, Carbohydrate). Create a function that applies different normalization strategies: divide amino acids by max value, lipids by mean, carbohydrates by median. Apply using pandas `groupby`.
#
# ### Exercise 2.3
# For time series data, calculate the area under the curve (AUC) for each metabolite using numpy's `trapz` function. Add AUC as a new column. Then identify metabolites whose AUC differs significantly between early (0-60 min) and late (60-240 min) time windows using pandas operations.
#
# ### Exercise 2.4
# Plot with matplotlib: Create a 2x2 subplot figure showing:
# - Top left: Line plot of 3 selected metabolites over time with error bars (SEM from 3 replicates)
# - Top right: Bar plot of AUC values for all metabolites
# - Bottom left: Correlation matrix heatmap of metabolites at 60 min time point
# - Bottom right: Box plot comparing metabolite distributions across time points
#
# ### Exercise 2.5
# Use pandas `rolling` with a custom window function (using numpy polyfit) to calculate the first derivative (rate of change) of each metabolite concentration over time. Identify time points where the rate of change is maximal for each metabolite. Output as DataFrame with columns: `['Metabolite', 'Time_max_rate', 'Max_rate']`.

# %% [markdown]
# ## Bonus: Sample Data Generation Code

# %%
import pandas as pd
import numpy as np

# For Set 1 - Protein expression
np.random.seed(42)
proteins = [f'Protein_{i}' for i in range(1, 21)]
compartments = np.random.choice(['Nucleus', 'Cytosol', 'Mitochondria', 'Membrane'], 20)
df_protein = pd.DataFrame({
    'Protein': proteins,
    'Control': np.random.lognormal(2, 0.5, 20),
    'Treatment_A': np.random.lognormal(2.5, 0.6, 20),
    'Treatment_B': np.random.lognormal(1.8, 0.4, 20),
    'MW_kDa': np.random.uniform(10, 150, 20),
    'Cellular_Compartment': compartments
})

# %%
df_protein
# Out:
#        Protein    Control  Treatment_A  Treatment_B      MW_kDa  \
# 0    Protein_1   5.843108     8.496181     6.941010   26.743194
# 1    Protein_2   9.691799    10.226514     2.988537  109.854270
# 2    Protein_3   5.860830     8.490739     6.886986  116.509907
# 3    Protein_4   5.854058    37.016617     5.186023   88.578808
# 4    Protein_5   8.339315    12.084234     4.614628  117.935405
# 5    Protein_6   2.838739     6.458347     7.726612   79.131383
# 6    Protein_7   3.119089    19.955942     9.137619   83.182596
# 7    Protein_8   5.578145     5.856158     8.780313   69.855743
# 8    Protein_9   4.453029    13.808967     4.324571   13.558678
# 9   Protein_10   8.646232     3.759169     5.345821   25.104800
# 10  Protein_11   4.692605     5.490879     6.906793   14.400086
# 11  Protein_12   3.646793    13.709880     8.937162   99.097458
# 12  Protein_13  15.376254    18.974196     4.994465   54.009837
# 13  Protein_14   6.600279    13.501772     5.616656   81.199897
# ...

# %% [markdown]
# Each exercise can be solved in 5-10 lines of code and reinforces different pandas capabilities relevant to biochemical data analysis.
