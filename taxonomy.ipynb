# %% [markdown]
# # Taxonomy pandas

# %% [markdown]
# Ask AI for help
#
# - in github is 13B_exam2021_source_cleaned_shorten.xlsx
# - download it and read into Pandas
# - ask AI how to download taxonomy lineages for the species, put the lineages into species
# - put the names in both lines and columns (square Pandas)
# - count similarities in % (so diagonal is 100%)
# - draw heatmap for it
